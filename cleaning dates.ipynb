# %%
import pandas as pd

# retrieved from https://data.noaa.gov/datasetsearch/
data = pd.read_csv("./data.csv", header=1) #get data from csv file


# data['datetime'] = pd.to_datetime(data['Date']) #create new datetime column
# data.drop('Date', axis=1, inplace=True) #drop old data column
# data = data.set_index('datetime') #indexing column is the new column created 2 lines ago

#index column is special, and takes it out of the pool of regular columns

print(data.columns) #old column headers
data.columns = ['DATE','TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'SNWD'] #change headers
print(data.columns) #new column headers
#dropna() will delete entire rows with no information
# Out:
# Index(['Date', 'TAVG (Degrees Fahrenheit)', 'TMAX (Degrees Fahrenheit)',
#        'TMIN (Degrees Fahrenheit)', 'PRCP (Inches)', 'SNOW (Inches)',
#        'SNWD (Inches)'],
#       dtype='object')
# Index(['DATE', 'TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'SNWD'], dtype='object')

# %%
print(data['DATE'].iloc[3698])

print(data['TMAX'].iloc[3698])
# Out:
# 1926-10-05
# 92.0

# %% [markdown]
# # data frame to csv through google drive and windows paths

# %%
from google.colab import drive
from pathlib import Path 
drive.mount('drive')

filepath = Path('drive/My Drive/Colab Notebooks/data_day3.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(filepath, header=True, index = True)

# windows_filepath = Path(r'C:\Users\horselessheadman\Desktop\dev\copy1.csv')
# data.to_csv(windows_filepath, header = True, index = False)
# Out:
# Mounted at drive

# %% [markdown]
# # documenting possible holes in data frame

# %%
#we know that 2001 has a missing day for 5/1/21

#https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
from datetime import date, timedelta

start_date = "1909-12-01"
end_date = "2010-12-31"

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2013, 1, 1)
end_date = date(2015, 6, 2)
for single_date in daterange(start_date, end_date):
    print(single_date.strftime("%Y-%m-%d"))
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# ...
