# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
#data from 1973 - 2019
data = pd.read_csv('.\\Area_burned_in_each_burn_severity_class_and_emissions_per_fire_1984_2020.csv' , header = 0)
data.info() #see what our data looks like
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1697 entries, 0 to 1696
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Event_ID               1697 non-null   object
#  1   Fire_Name              1697 non-null   object
#  2   Lat                    1697 non-null   float64
#  3   Long                   1697 non-null   float64
#  4   Fire_Year              1697 non-null   int64
#  5   Fire_Month             1697 non-null   int64
#  6   Total_area_burned(ha)  1697 non-null   float64
#  7   Unchanged(ha)          1697 non-null   float64
#  8   Low_Severity(ha)       1697 non-null   float64
#  9   Moderate_Severity(ha)  1697 non-null   float64
#  10  High_Severity(ha)      1697 non-null   float64
#  11  Grass_Burned(ha)       1697 non-null   float64
#  12  CO2(kg)                1697 non-null   float64
#  13  CO(kg)                 1697 non-null   float64
# ...

# %% [markdown]
# drop columns that aren't needed

# %%
columns_to_drop = ['Event_ID', 'Unchanged(ha)', 'Low_Severity(ha)', 'Grass_Burned(ha)',
       'CO2(kg)', 'CO(kg)', 'CH4(kg)', 'NMOC(kg)', 'SO2(kg)', 'NH3(kg)',
       'NO(kg)', 'NO2(kg)', 'NOx(kg)', 'PM2.5(kg)', 'OC(kg)', 'BC(kg)']
data = data.drop(columns = columns_to_drop)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1697 entries, 0 to 1696
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Fire_Name              1697 non-null   object
#  1   Lat                    1697 non-null   float64
#  2   Long                   1697 non-null   float64
#  3   Fire_Year              1697 non-null   int64
#  4   Fire_Month             1697 non-null   int64
#  5   Total_area_burned(ha)  1697 non-null   float64
#  6   Moderate_Severity(ha)  1697 non-null   float64
#  7   High_Severity(ha)      1697 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 106.2+ KB

# %% [markdown]
# Export to clean csv

# %%
data.to_csv('Clean_cal1984.csv',  encoding = 'utf-8')

# %%
data
# Out:
#        Fire_Name        Lat        Long  Fire_Year  Fire_Month  \
# 0        PROCTOR  32.682000 -116.886000       1984           4
# 1        AGUANGA  33.413000 -116.873000       1984           5
# 2     LOMA RIDGE  33.750000 -117.729000       1984           6
# 3          LYTLE  34.285000 -117.554000       1984           5
# 4     SQUAW FLAT  34.443000 -118.896000       1984          10
# ...          ...        ...         ...        ...         ...
# 1692      WALKER  38.070623 -120.706163       2020           6
# 1693        BENA  35.306591 -118.649157       2020           7
# 1694  STAGECOACH  35.453445 -118.484881       2020           8
# 1695        PASS  37.046313 -121.163309       2020           6
# 1696     WILLOWS  39.375003 -121.332452       2020           9
#
#       Total_area_burned(ha)  Moderate_Severity(ha)  High_Severity(ha)
# 0                   1222.20                 691.38             229.86
# ...
