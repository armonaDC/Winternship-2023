# %%
import pandas as pd
import numpy as np
data = pd.read_csv("./1984_2020.csv")
data.sort_values(by=["Fire_Year","Fire_Month"], inplace=True)

# %%
#for index, row in data.iterrows():
    # print(row['Lat'], row['Long'])
    #if row.Lat < 42.000 and row.Lat > 37.827 and row.Long < 124.000 and row.Long > 119.997:
      #print(row)
      #  Set

# %%
#Region 1
newdata = data[(data["Lat"] < 42.000) & (data["Lat"] > 37.827) & (data["Long"] > -124.000) & (data["Long"] < -119.997)]
#Region 1: filter all the index satisfied the condition of long and lat
newdata.to_csv('./region_1.csv')
newdata

# data.set_index(["Lat","Long"], inplace=True)
#set = (data.Lat < 42.000) & (data.Lat > 37.827) & (data.Long < 124.000) & (data.Long > 119.997)
# print(data.index.columns)
#data.index.levels
# Out:
#                                            Event_ID    Fire_Name        Lat  \
# 40                            CA3800412064719840624  SALT SPRING  38.004000
# 13                            CA3978412169619840702      BIDWELL  39.784000
# 14                            CA3998112259119840712       LOWERY  39.981000
# 16                            CA4007812006619840705       TURTLE  40.078000
# 15                            CA4003412014019840821       SECOND  40.034000
# ...                                             ...          ...        ...
# 1658     CA20200908_20201108_UCM244_FORK_CF00027219         FORK  38.987101
# 1660          CA20200909_NA_UCM253_DEVIL_CF00007084        DEVIL  41.924444
# 1662   CA20200908_20201212_UCM265_SLATER_CF00007035       SLATER  41.945897
# 1696    CA20200909_20201013_UCM9_WILLOWS_CF00021423      WILLOWS  39.375003
# 1680  CA20201117_20201123_UCM331_LAURA_2_CF00006431      LAURA 2  40.062617
#
#             Long  Fire_Year  Fire_Month  Total_area_burned(ha)  Unchanged(ha)  \
# 40   -120.647000       1984           6                1957.23           0.36
# 13   -121.696000       1984           7                2432.25           3.33
# 14   -122.591000       1984           7                1158.93           3.42
# 16   -120.066000       1984           7                1610.82           0.00
# 15   -120.140000       1984           8                 486.09           1.53
# ...          ...        ...         ...                    ...            ...
# 1658 -120.424249       2020           9                 674.19           0.00
# 1660 -123.233493       2020           9                3559.59           0.54
# 1662 -123.501025       2020           9               45117.00          45.36
# 1696 -121.332452       2020           9                 526.68           0.00
# 1680 -120.089579       2020          11                 929.43           0.00
#
#       Low_Severity(ha)  Moderate_Severity(ha)  ...       CH4(kg)     NMOC(kg)  \
# 40               56.43                1636.56  ...  4.299302e+05   3136425.84
# 13             1230.39                1151.73  ...  6.351315e+05   4227301.44
# 14              237.15                 739.71  ...  8.693917e+04    926285.04
# 16              401.49                1208.88  ...  1.584902e+05   1595635.92
# 15              414.54                  64.89  ...  8.594501e+04    677814.48
# ...                ...                    ...  ...           ...          ...
# 1658            166.59                 328.50  ...  1.699844e+05   1108803.60
# 1660           1209.96                1584.90  ...  7.063752e+05   4668260.40
# 1662           7713.36                6458.13  ...  1.383008e+07  89959301.28
# 1696            286.47                 204.57  ...  1.031236e+05    673912.80
# 1680             68.58                 753.39  ...  5.325454e+04    556638.48
#
#            SO2(kg)       NH3(kg)       NO(kg)       NO2(kg)      NOx(kg)  \
# 40    1.153572e+05  1.711144e+05   131922.585  1.276080e+05   188996.814
# 13    1.632643e+05  2.117076e+05   162955.602  1.738387e+05   221324.049
# 14    3.148279e+04  6.229844e+04    51750.927  3.921380e+04    82206.333
# 16    5.272990e+04  1.060173e+05    84911.175  6.525848e+04   134234.685
# 15    2.407084e+04  3.927728e+04    30449.349  2.745550e+04    45116.001
# ...            ...           ...          ...           ...          ...
# 1658  4.331017e+04  5.436953e+04    41846.229  4.572134e+04    56026.323
# 1660  1.818939e+05  2.315429e+05   179253.315  1.929919e+05   242122.527
# 1662  3.519109e+06  4.397973e+06  3384558.108  3.710588e+06  4522024.368
# 1696  2.629223e+04  3.311225e+04    25481.124  2.777821e+04    34162.587
# 1680  1.725908e+04  3.819699e+04    29567.889  2.189105e+04    47380.734
#
#          PM2.5(kg)        OC(kg)        BC(kg)
# 40    1.288748e+06  1.233605e+06  8.478412e+04
# 13    1.837199e+06  1.955861e+06  8.050482e+04
# 14    3.047905e+05  1.484958e+05  4.795260e+04
# 16    5.441391e+05  3.062664e+05  7.854913e+04
# 15    2.658258e+05  2.297076e+05  2.249669e+04
# ...            ...           ...           ...
# 1658  4.879808e+05  5.308600e+05  1.905287e+04
# 1660  2.036705e+06  2.184684e+06  8.546458e+04
# 1662  3.966108e+07  4.327497e+07  1.522259e+06
# 1696  2.962499e+05  3.216535e+05  1.169740e+04
# 1680  1.872199e+05  9.753007e+04  2.902349e+04
#
# [621 rows x 24 columns]

# %%
#Region 2
newdata = data[(data["Lat"] < 40.192) & (data["Lat"] > 35.127) & (data["Long"] > -122.192) & (data["Long"] < -118.047)]
newdata.to_csv('./region_2.csv')
newdata
# Out:
#                                                Event_ID      Fire_Name  \
# 34                                CA3607412018819840329        FK 1817
# 31                                CA3525312054719840529        MORETZZ
# 32                                CA3561111844619840526        WOODROW
# 33                                CA3589912013419840525       FLAT TOP
# 35                                CA3626012031719840525     OIL FIELDS
# ...                                                 ...            ...
# 1659        CA20200904_20201224_UCM247_CREEK_CF00001391          CREEK
# 1696        CA20200909_20201013_UCM9_WILLOWS_CF00021423        WILLOWS
# 1679     CA20201004_20201011_UCM325_BACCARAT_CF00030788       BACCARAT
# 1680      CA20201117_20201123_UCM331_LAURA_2_CF00006431        LAURA 2
# 1681  CA20201117_20201130_UCM332_MOUNTAIN_VIEW_CF000...  MOUNTAIN VIEW
#
#             Lat        Long  Fire_Year  Fire_Month  Total_area_burned(ha)  \
# 34    36.074000 -120.188000       1984           3                 592.20
# 31    35.253000 -120.547000       1984           5                 641.61
# 32    35.611000 -118.446000       1984           5                 452.34
# 33    35.899000 -120.134000       1984           5                2706.75
# 35    36.260000 -120.317000       1984           5                 459.09
# ...         ...         ...        ...         ...                    ...
# 1659  37.332856 -119.276384       2020           9              153659.34
# 1696  39.375003 -121.332452       2020           9                 526.68
# 1679  39.776831 -119.956940       2020          10                   6.66
# 1680  40.062617 -120.089579       2020          11                 929.43
# 1681  38.557839 -119.411412       2020          11                5123.52
#
#       Unchanged(ha)  Low_Severity(ha)  Moderate_Severity(ha)  ...  \
# 34            39.87              0.00                 463.32  ...
# 31             0.00            222.03                 410.94  ...
# 32             0.00              0.00                 448.29  ...
# 33           172.62              0.00                 996.57  ...
# 35             1.08              0.00                  90.63  ...
# ...             ...               ...                    ...  ...
# 1659        1877.94          22777.92               58350.33  ...
# 1696           0.00            286.47                 204.57  ...
# 1679           0.00              5.85                   0.81  ...
# 1680           0.00             68.58                 753.39  ...
# 1681          20.52            626.85                1685.07  ...
#
#            CH4(kg)      NMOC(kg)       SO2(kg)       NH3(kg)        NO(kg)  \
# 34    2.993749e+04  3.225182e+05  1.221598e+04  2.100833e+04  1.901902e+04
# 31    1.021913e+05  7.418621e+05  2.872063e+04  3.946829e+04  3.202690e+04
# 32    5.747968e+04  5.521421e+05  1.778894e+04  3.629490e+04  2.809991e+04
# 33    8.952688e+04  9.386201e+05  4.453300e+04  5.503159e+04  6.076653e+04
# 35    1.084304e+04  1.096834e+05  6.535066e+03  5.518885e+03  7.894314e+03
# ...            ...           ...           ...           ...           ...
# 1659  3.679807e+07  2.528428e+08  9.648033e+06  1.303701e+07  1.009880e+07
# 1696  1.031236e+05  6.739128e+05  2.629223e+04  3.311225e+04  2.548112e+04
# 1679  6.886440e+02  7.512480e+03  2.285046e+02  5.258736e+02  4.069260e+02
# 1680  5.325454e+04  5.566385e+05  1.725908e+04  3.819699e+04  2.956789e+04
# 1681  8.272019e+05  6.435783e+06  2.342776e+05  3.665891e+05  2.890543e+05
#
#            NO2(kg)       NOx(kg)     PM2.5(kg)        OC(kg)        BC(kg)
# 34    1.487562e+04  2.984429e+04  1.039037e+05  4.779896e+04  1.630683e+04
# 31    3.149397e+04  4.547572e+04  3.040283e+05  2.921608e+05  1.913004e+04
# 32    2.188601e+04  4.421857e+04  1.940653e+05  1.212313e+05  2.595684e+04
# 33    5.156710e+04  9.220235e+04  2.959464e+05  1.374672e+05  4.206853e+04
# 35    7.249833e+03  1.154876e+04  3.367858e+04  1.596100e+04  4.103363e+03
# ...            ...           ...           ...           ...           ...
# 1659  1.040489e+07  1.399089e+07  1.076820e+08  1.106328e+08  5.514740e+06
# 1696  2.777821e+04  3.416259e+04  2.962499e+05  3.216535e+05  1.169740e+04
# 1679  2.942388e+02  6.573420e+02  2.472858e+03  1.158174e+03  4.100562e+02
# 1680  2.189105e+04  4.738073e+04  1.872199e+05  9.753007e+04  2.902349e+04
# 1681  2.650071e+05  4.249442e+05  2.538897e+06  2.232960e+06  2.049375e+05
#
# [701 rows x 24 columns]

# %%
#Region 3
newdata = data[(data["Lat"] < 37.424) & (data["Lat"] > 34.806) & (data["Long"] > -118.818) & (data["Long"] < -114.134)]
newdata.to_csv('./region_3.csv')
newdata
# Out:
#                                                Event_ID    Fire_Name  \
# 32                                CA3561111844619840526      WOODROW
# 8                                 CA3557911838819840707      BODFISH
# 62                                CA3544311877719850503     ADELAIDE
# 63                                CA3545811870719850628     RICH BAR
# 78                                CA3695911862619850625    DOUGHERTY
# ...                                                 ...          ...
# 1657       CA20200819_20210104_UCM243_CASTLE_CF00002541       CASTLE
# 1672         CA20200815_20200912_UCM314_DOME_CF00012356         DOME
# 1674      CA20200821_20201229_UCM317_MORAINE_CF00000091      MORAINE
# 1675  CA20200816_20201228_UCM319_RATTLESNAKE_CF00000080  RATTLESNAKE
# 1694    CA20200803_20200803_UCM74_STAGECOACH_CF02033315   STAGECOACH
#
#             Lat        Long  Fire_Year  Fire_Month  Total_area_burned(ha)  \
# 32    35.611000 -118.446000       1984           5                 452.34
# 8     35.579000 -118.388000       1984           7                9384.21
# 62    35.443000 -118.777000       1985           5                 426.15
# 63    35.458000 -118.707000       1985           6                3294.18
# 78    36.959000 -118.626000       1985           6                 670.59
# ...         ...         ...        ...         ...                    ...
# 1657  36.216973 -118.545892       2020           8               68846.58
# 1672  35.293545 -115.584652       2020           8               17861.22
# 1674  36.727191 -118.551611       2020           8                 526.32
# 1675  36.430343 -118.415067       2020           8                3354.03
# 1694  35.453445 -118.484881       2020           8                3115.08
#
#       Unchanged(ha)  Low_Severity(ha)  Moderate_Severity(ha)  ...  \
# 32             0.00              0.00                 448.29  ...
# 8              0.72           5105.16                3603.60  ...
# 62            31.77            223.11                 168.66  ...
# 63             1.80           1175.04                2081.16  ...
# 78             0.09            179.46                 298.44  ...
# ...             ...               ...                    ...  ...
# 1657         652.86          10095.30               26859.51  ...
# 1672           0.63           7155.81               10670.40  ...
# 1674          16.83            290.07                 201.42  ...
# 1675          44.46           1246.32                1478.25  ...
# 1694           0.09            353.43                2242.44  ...
#
#            CH4(kg)      NMOC(kg)       SO2(kg)       NH3(kg)       NO(kg)  \
# 32    5.747968e+04  5.521421e+05  1.778894e+04  3.629490e+04    28099.908
# 8     1.764522e+06  1.369784e+07  4.889210e+05  7.851947e+05   606988.143
# 62    3.094240e+04  3.079152e+05  1.091203e+04  1.991655e+04    16770.978
# 63    5.791258e+05  4.609133e+06  1.625256e+05  2.691405e+05   208178.550
# 78    1.914302e+05  1.271769e+06  4.919394e+04  6.355493e+04    48949.398
# ...            ...           ...           ...           ...          ...
# 1657  1.883475e+07  1.257298e+08  4.862011e+06  6.307036e+06  4871243.853
# 1672  1.837264e+06  1.999437e+07  6.090781e+05  1.397914e+06  1082047.968
# 1674  8.062433e+04  5.614855e+05  2.151655e+04  2.917318e+04    22888.809
# 1675  6.211114e+05  4.288664e+06  1.680807e+05  2.191925e+05   175511.088
# 1694  4.826834e+05  4.119866e+06  1.404381e+05  2.524227e+05   195446.862
#
#            NO2(kg)      NOx(kg)     PM2.5(kg)        OC(kg)        BC(kg)
# 32    2.188601e+04    44218.575  1.940653e+05  1.212313e+05  2.595684e+04
# 8     5.544422e+05   894041.793  5.423580e+06  4.790175e+06  4.384793e+05
# 62    1.325578e+04    26227.827  1.047941e+05  5.985273e+04  1.462841e+04
# 63    1.861281e+05   309643.182  1.798590e+06  1.534783e+06  1.563807e+05
# 78    5.233612e+04    66393.945  5.533168e+05  5.902289e+05  2.399313e+04
# ...            ...          ...           ...           ...           ...
# 1657  5.181715e+06  6626948.121  5.452528e+07  5.785638e+07  2.421760e+06
# 1672  7.835391e+05  1747069.398  6.589117e+06  3.105399e+06  1.088528e+06
# 1674  2.330114e+04    31916.862  2.368573e+05  2.395223e+05  1.279837e+04
# 1675  1.809906e+05   242955.450  1.814939e+06  1.852440e+06  9.317893e+04
# 1694  1.652619e+05   297801.684  1.544650e+06  1.187603e+06  1.609667e+05
#
# [154 rows x 24 columns]

# %%
data1 = pd.read_csv("./region_1.csv")
data2 = pd.read_csv("./region_2.csv")
data3 = pd.read_csv("./region_3.csv")
print(data1.columns)
print(data2.columns)
print(data3.columns)
#Check if all columns intact

# %%
# Out:
# Index(['Unnamed: 0', 'Event_ID', 'Fire_Name', 'Lat', 'Long', 'Fire_Year',
#        'Fire_Month', 'Total_area_burned(ha)', 'Unchanged(ha)',
#        'Low_Severity(ha)', 'Moderate_Severity(ha)', 'High_Severity(ha)',
#        'Grass_Burned(ha)', 'CO2(kg)', 'CO(kg)', 'CH4(kg)', 'NMOC(kg)',
#        'SO2(kg)', 'NH3(kg)', 'NO(kg)', 'NO2(kg)', 'NOx(kg)', 'PM2.5(kg)',
#        'OC(kg)', 'BC(kg)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Event_ID', 'Fire_Name', 'Lat', 'Long', 'Fire_Year',
#        'Fire_Month', 'Total_area_burned(ha)', 'Unchanged(ha)',
#        'Low_Severity(ha)', 'Moderate_Severity(ha)', 'High_Severity(ha)',
#        'Grass_Burned(ha)', 'CO2(kg)', 'CO(kg)', 'CH4(kg)', 'NMOC(kg)',
#        'SO2(kg)', 'NH3(kg)', 'NO(kg)', 'NO2(kg)', 'NOx(kg)', 'PM2.5(kg)',
#        'OC(kg)', 'BC(kg)'],
#       dtype='object')
# Index(['Unnamed: 0', 'Event_ID', 'Fire_Name', 'Lat', 'Long', 'Fire_Year',
#        'Fire_Month', 'Total_area_burned(ha)', 'Unchanged(ha)',
#        'Low_Severity(ha)', 'Moderate_Severity(ha)', 'High_Severity(ha)',
#        'Grass_Burned(ha)', 'CO2(kg)', 'CO(kg)', 'CH4(kg)', 'NMOC(kg)',
#        'SO2(kg)', 'NH3(kg)', 'NO(kg)', 'NO2(kg)', 'NOx(kg)', 'PM2.5(kg)',
#        'OC(kg)', 'BC(kg)'],
#       dtype='object')

# %%
#Merge into union, universal - union = region 4
union = pd.concat([data1, data2, data3], ignore_index = True) 
newdata = data[data.index.isin(union.index) == False]
newdata.to_csv('./region_4.csv')
newdata

#union = data1.merge(data2, how = 'outer')
#union = union.merge(data3, how = 'outer')
#union.sort_values(by=["Fire_Year"], inplace=True)
#union
# Out:
#                                                Event_ID      Fire_Name  \
# 1493                              CA3606812023620170420          JAYNE
# 1495                              CA3611812036120170518          ELM 2
# 1482                              CA3539711882220170630         TARINA
# 1483                              CA3539712049820170626           HILL
# 1485                              CA3557211858220170618        HIGHWAY
# ...                                                 ...            ...
# 1680      CA20201117_20201123_UCM331_LAURA_2_CF00006431        LAURA 2
# 1681  CA20201117_20201130_UCM332_MOUNTAIN_VIEW_CF000...  MOUNTAIN VIEW
# 1637      CA20201201_20201213_UCM183_AIRPORT_CF00154602        AIRPORT
# 1639    CA20201213_20201214_UCM187_SANDERSON_CF00160421      SANDERSON
# 1688          CA20201203_20201207_UCM41_BOND_CF20136890           BOND
#
#             Lat        Long  Fire_Year  Fire_Month  Total_area_burned(ha)  \
# 1493  36.061000 -120.274000       2017           4                1892.16
# 1495  36.075000 -120.405000       2017           5                4357.44
# 1482  35.385000 -118.793000       2017           6                 508.86
# 1483  35.405000 -120.481000       2017           6                 765.90
# 1485  35.586000 -118.574000       2017           6                 686.07
# ...         ...         ...        ...         ...                    ...
# 1680  40.062617 -120.089579       2020          11                 929.43
# 1681  38.557839 -119.411412       2020          11                5123.52
# 1637  33.902902 -117.627691       2020          12                 429.66
# 1639  33.900438 -117.063063       2020          12                 784.62
# 1688  33.739796 -117.662660       2020          12                2685.06
#
#       Unchanged(ha)  Low_Severity(ha)  Moderate_Severity(ha)  ...     CH4(kg)  \
# 1493          36.09            282.96                 629.73  ...   16971.354
# 1495         238.41            855.72                2228.40  ...  131214.033
# 1482           0.81             52.65                 454.77  ...      16.704
# 1483           2.79            288.36                 447.75  ...   84681.864
# 1485           0.00            225.63                 454.95  ...   35783.568
# ...             ...               ...                    ...  ...         ...
# 1680           0.00             68.58                 753.39  ...   53254.539
# 1681          20.52            626.85                1685.07  ...  827201.907
# 1637          10.26            282.15                 107.37  ...   27866.709
# 1639           2.97            148.95                 596.88  ...   59186.835
# 1688           6.39            238.41                1746.54  ...  224425.449
#
#         NMOC(kg)      SO2(kg)      NH3(kg)      NO(kg)      NO2(kg)  \
# 1493   171294.48   13391.2323    6659.3016   14546.295   14337.8874
# 1495  1340159.76   50767.7454   85558.8645   76548.789   61141.7691
# 1482      161.28      17.2800       3.2256      16.704      17.8560
# 1483   839710.08   26643.8178   56144.4768   43445.142   33167.8260
# 1485   275398.56    9944.4294   15638.2308   12171.762   11225.2320
# ...          ...          ...          ...         ...          ...
# 1680   556638.48   17259.0840   38196.9891   29567.889   21891.0465
# 1681  6435782.64  234277.5708  366589.1439  289054.269  265007.0997
# 1637   181414.08    7100.2827    8872.8183    6836.400    7488.5607
# 1639   629028.00   19597.0005   43359.8229   33840.864   24925.1877
# 1688  2232208.08   71575.6284  148965.4845  116264.511   88947.5679
#
#          NOx(kg)    PM2.5(kg)       OC(kg)       BC(kg)
# 1493   20509.983    48704.805    19870.695    4938.7977
# 1495  119179.296   445196.970   236075.436   64056.4452
# 1482      22.464       41.472       14.976       2.1312
# 1483   68867.982   290250.558   170014.338   41147.0514
# 1485   17846.622   109506.762    97808.598    8596.7010
# ...          ...          ...          ...          ...
# 1680   47380.734   187219.872    97530.066   29023.4862
# 1681  424944.198  2538897.228  2232959.526  204937.4502
# 1637    9138.609    79930.917    87134.985    3080.8899
# 1639   54321.003   209489.931   104597.991   33294.7809
# 1688  184145.994   769291.452   446948.154  109413.1386
#
# [221 rows x 24 columns]

# %%
from datetime import date, timedelta
data1 = pd.read_csv("./region_1.csv")
data1['TSLF'] = 0
data1.sort_values(by=["Fire_Year","Fire_Month"], inplace=True)
#while data1['TSLF'].isna()
data1.reset_index(inplace=True,drop=True)
for i in range(0, len(data1)-1):
    if data1.iloc[i+1]['Fire_Year'] > data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF'] = (((data1.iloc[i+1]['Fire_Year'] -  data1.iloc[i]['Fire_Year']) * 12) + data1.iloc[i+1]['Fire_Month']) - data1.iloc[i]['Fire_Month']
    if data1.iloc[i+1]['Fire_Year'] == data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF']  = data1.iloc[i+1]['Fire_Month'] - data1.iloc[i]['Fire_Month']
data1.to_csv('./region_1.csv')
data1

# data1['TSLF'].isna() & 
#data1['Fire_Year'] = data1['Fire_Year'].astype('string')
#data1['Fire_Month'] = data1['Fire_Month'].astype('string')
#data1['Date'] = data1['Fire_Year'].str.cat(data1['Fire_Month'], sep='')
#data1['Date'] = pd.to_datetime(data1['Date'], format='%Y%m')
#data1['Date'] = data1['Date'].dt.date.apply(lambda x: x.strftime('%Y-%m'))
#data1['Fire_Year'] = data1['Fire_Year'].astype('int')
#data1['Fire_Month'] = data1['Fire_Month'].astype('int')
# Out:
#      Unnamed: 0                                       Event_ID    Fire_Name  \
# 0            40                          CA3800412064719840624  SALT SPRING
# 1            13                          CA3978412169619840702      BIDWELL
# 2            14                          CA3998112259119840712       LOWERY
# 3            16                          CA4007812006619840705       TURTLE
# 4            15                          CA4003412014019840821       SECOND
# ..          ...                                            ...          ...
# 616        1658     CA20200908_20201108_UCM244_FORK_CF00027219         FORK
# 617        1660          CA20200909_NA_UCM253_DEVIL_CF00007084        DEVIL
# 618        1662   CA20200908_20201212_UCM265_SLATER_CF00007035       SLATER
# 619        1696    CA20200909_20201013_UCM9_WILLOWS_CF00021423      WILLOWS
# 620        1680  CA20201117_20201123_UCM331_LAURA_2_CF00006431      LAURA 2
#
#            Lat        Long  Fire_Year  Fire_Month  Total_area_burned(ha)  \
# 0    38.004000 -120.647000       1984           6                1957.23
# 1    39.784000 -121.696000       1984           7                2432.25
# 2    39.981000 -122.591000       1984           7                1158.93
# 3    40.078000 -120.066000       1984           7                1610.82
# 4    40.034000 -120.140000       1984           8                 486.09
# ..         ...         ...        ...         ...                    ...
# 616  38.987101 -120.424249       2020           9                 674.19
# 617  41.924444 -123.233493       2020           9                3559.59
# 618  41.945897 -123.501025       2020           9               45117.00
# 619  39.375003 -121.332452       2020           9                 526.68
# 620  40.062617 -120.089579       2020          11                 929.43
#
#      Unchanged(ha)  Low_Severity(ha)  ...     NMOC(kg)       SO2(kg)  \
# 0             0.36             56.43  ...   3136425.84  1.153572e+05
# 1             3.33           1230.39  ...   4227301.44  1.632643e+05
# 2             3.42            237.15  ...    926285.04  3.148279e+04
# 3             0.00            401.49  ...   1595635.92  5.272990e+04
# 4             1.53            414.54  ...    677814.48  2.407084e+04
# ..             ...               ...  ...          ...           ...
# 616           0.00            166.59  ...   1108803.60  4.331017e+04
# 617           0.54           1209.96  ...   4668260.40  1.818939e+05
# 618          45.36           7713.36  ...  89959301.28  3.519109e+06
# 619           0.00            286.47  ...    673912.80  2.629223e+04
# 620           0.00             68.58  ...    556638.48  1.725908e+04
#
#           NH3(kg)       NO(kg)       NO2(kg)      NOx(kg)     PM2.5(kg)  \
# 0    1.711144e+05   131922.585  1.276080e+05   188996.814  1.288748e+06
# 1    2.117076e+05   162955.602  1.738387e+05   221324.049  1.837199e+06
# 2    6.229844e+04    51750.927  3.921380e+04    82206.333  3.047905e+05
# 3    1.060173e+05    84911.175  6.525848e+04   134234.685  5.441391e+05
# 4    3.927728e+04    30449.349  2.745550e+04    45116.001  2.658258e+05
# ..            ...          ...           ...          ...           ...
# 616  5.436953e+04    41846.229  4.572134e+04    56026.323  4.879808e+05
# 617  2.315429e+05   179253.315  1.929919e+05   242122.527  2.036705e+06
# 618  4.397973e+06  3384558.108  3.710588e+06  4522024.368  3.966108e+07
# 619  3.311225e+04    25481.124  2.777821e+04    34162.587  2.962499e+05
# 620  3.819699e+04    29567.889  2.189105e+04    47380.734  1.872199e+05
#
#            OC(kg)        BC(kg)  TSLF
# 0    1.233605e+06  8.478412e+04     1
# 1    1.955861e+06  8.050482e+04     0
# 2    1.484958e+05  4.795260e+04     0
# 3    3.062664e+05  7.854913e+04     1
# 4    2.297076e+05  2.249669e+04     0
# ..            ...           ...   ...
# 616  5.308600e+05  1.905287e+04     0
# 617  2.184684e+06  8.546458e+04     0
# 618  4.327497e+07  1.522259e+06     0
# 619  3.216535e+05  1.169740e+04     2
# 620  9.753007e+04  2.902349e+04     0
#
# [621 rows x 26 columns]

# %%
#data1.iloc[1]['TSLF'] = data1.iloc[2]['Date'] - data1.iloc[1]['Date']

test = data1.iloc[i]['TSLF']
print(type(test))
print(data1.iloc[i]['TSLF'])
# Out:
# <class 'numpy.float64'>
# nan

# %%
from datetime import date, timedelta
data1 = pd.read_csv("./region_2.csv")
data1['TSLF'] = 0
data1.sort_values(by=["Fire_Year","Fire_Month"], inplace=True)
data1.reset_index(inplace=True,drop=True)
for i in range(0, len(data1)-1):
    if data1.iloc[i+1]['Fire_Year'] > data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF'] = (((data1.iloc[i+1]['Fire_Year'] -  data1.iloc[i]['Fire_Year']) * 12) + data1.iloc[i+1]['Fire_Month']) - data1.iloc[i]['Fire_Month']
    if data1.iloc[i+1]['Fire_Year'] == data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF']  = data1.iloc[i+1]['Fire_Month'] - data1.iloc[i]['Fire_Month']
data1
data1.to_csv('./region_2.csv')
data1
# Out:
#      Unnamed: 0                                           Event_ID  \
# 0            34                              CA3607412018819840329
# 1            31                              CA3525312054719840529
# 2            32                              CA3561111844619840526
# 3            33                              CA3589912013419840525
# 4            35                              CA3626012031719840525
# ..          ...                                                ...
# 696        1659        CA20200904_20201224_UCM247_CREEK_CF00001391
# 697        1696        CA20200909_20201013_UCM9_WILLOWS_CF00021423
# 698        1679     CA20201004_20201011_UCM325_BACCARAT_CF00030788
# 699        1680      CA20201117_20201123_UCM331_LAURA_2_CF00006431
# 700        1681  CA20201117_20201130_UCM332_MOUNTAIN_VIEW_CF000...
#
#          Fire_Name        Lat        Long  Fire_Year  Fire_Month  \
# 0          FK 1817  36.074000 -120.188000       1984           3
# 1          MORETZZ  35.253000 -120.547000       1984           5
# 2          WOODROW  35.611000 -118.446000       1984           5
# 3         FLAT TOP  35.899000 -120.134000       1984           5
# 4       OIL FIELDS  36.260000 -120.317000       1984           5
# ..             ...        ...         ...        ...         ...
# 696          CREEK  37.332856 -119.276384       2020           9
# 697        WILLOWS  39.375003 -121.332452       2020           9
# 698       BACCARAT  39.776831 -119.956940       2020          10
# 699        LAURA 2  40.062617 -120.089579       2020          11
# 700  MOUNTAIN VIEW  38.557839 -119.411412       2020          11
#
#      Total_area_burned(ha)  Unchanged(ha)  Low_Severity(ha)  ...  \
# 0                   592.20          39.87              0.00  ...
# 1                   641.61           0.00            222.03  ...
# 2                   452.34           0.00              0.00  ...
# 3                  2706.75         172.62              0.00  ...
# 4                   459.09           1.08              0.00  ...
# ..                     ...            ...               ...  ...
# 696              153659.34        1877.94          22777.92  ...
# 697                 526.68           0.00            286.47  ...
# 698                   6.66           0.00              5.85  ...
# 699                 929.43           0.00             68.58  ...
# 700                5123.52          20.52            626.85  ...
#
#          NMOC(kg)       SO2(kg)       NH3(kg)        NO(kg)       NO2(kg)  \
# 0    3.225182e+05  1.221598e+04  2.100833e+04  1.901902e+04  1.487562e+04
# 1    7.418621e+05  2.872063e+04  3.946829e+04  3.202690e+04  3.149397e+04
# 2    5.521421e+05  1.778894e+04  3.629490e+04  2.809991e+04  2.188601e+04
# 3    9.386201e+05  4.453300e+04  5.503159e+04  6.076653e+04  5.156710e+04
# 4    1.096834e+05  6.535066e+03  5.518885e+03  7.894314e+03  7.249833e+03
# ..            ...           ...           ...           ...           ...
# 696  2.528428e+08  9.648033e+06  1.303701e+07  1.009880e+07  1.040489e+07
# 697  6.739128e+05  2.629223e+04  3.311225e+04  2.548112e+04  2.777821e+04
# 698  7.512480e+03  2.285046e+02  5.258736e+02  4.069260e+02  2.942388e+02
# 699  5.566385e+05  1.725908e+04  3.819699e+04  2.956789e+04  2.189105e+04
# 700  6.435783e+06  2.342776e+05  3.665891e+05  2.890543e+05  2.650071e+05
#
#           NOx(kg)     PM2.5(kg)        OC(kg)        BC(kg)  TSLF
# 0    2.984429e+04  1.039037e+05  4.779896e+04  1.630683e+04     2
# 1    4.547572e+04  3.040283e+05  2.921608e+05  1.913004e+04     0
# 2    4.421857e+04  1.940653e+05  1.212313e+05  2.595684e+04     0
# 3    9.220235e+04  2.959464e+05  1.374672e+05  4.206853e+04     0
# 4    1.154876e+04  3.367858e+04  1.596100e+04  4.103363e+03     0
# ..            ...           ...           ...           ...   ...
# 696  1.399089e+07  1.076820e+08  1.106328e+08  5.514740e+06     0
# 697  3.416259e+04  2.962499e+05  3.216535e+05  1.169740e+04     1
# 698  6.573420e+02  2.472858e+03  1.158174e+03  4.100562e+02     1
# 699  4.738073e+04  1.872199e+05  9.753007e+04  2.902349e+04     0
# 700  4.249442e+05  2.538897e+06  2.232960e+06  2.049375e+05     0
#
# [701 rows x 26 columns]

# %%
from datetime import date, timedelta
data1 = pd.read_csv("./region_3.csv")
data1['TSLF'] = 0
data1.sort_values(by=["Fire_Year","Fire_Month"], inplace=True)
data1.reset_index(inplace=True,drop=True)
for i in range(0, len(data1)-1):
    if data1.iloc[i+1]['Fire_Year'] > data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF'] = (((data1.iloc[i+1]['Fire_Year'] -  data1.iloc[i]['Fire_Year']) * 12) + data1.iloc[i+1]['Fire_Month']) - data1.iloc[i]['Fire_Month']
    if data1.iloc[i+1]['Fire_Year'] == data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF']  = data1.iloc[i+1]['Fire_Month'] - data1.iloc[i]['Fire_Month']
data1
data1.to_csv('./region_3.csv')
data1
# Out:
#      Unnamed: 0                                           Event_ID  \
# 0            32                              CA3561111844619840526
# 1             8                              CA3557911838819840707
# 2            62                              CA3544311877719850503
# 3            63                              CA3545811870719850628
# 4            78                              CA3695911862619850625
# ..          ...                                                ...
# 149        1657       CA20200819_20210104_UCM243_CASTLE_CF00002541
# 150        1672         CA20200815_20200912_UCM314_DOME_CF00012356
# 151        1674      CA20200821_20201229_UCM317_MORAINE_CF00000091
# 152        1675  CA20200816_20201228_UCM319_RATTLESNAKE_CF00000080
# 153        1694    CA20200803_20200803_UCM74_STAGECOACH_CF02033315
#
#        Fire_Name        Lat        Long  Fire_Year  Fire_Month  \
# 0        WOODROW  35.611000 -118.446000       1984           5
# 1        BODFISH  35.579000 -118.388000       1984           7
# 2       ADELAIDE  35.443000 -118.777000       1985           5
# 3       RICH BAR  35.458000 -118.707000       1985           6
# 4      DOUGHERTY  36.959000 -118.626000       1985           6
# ..           ...        ...         ...        ...         ...
# 149       CASTLE  36.216973 -118.545892       2020           8
# 150         DOME  35.293545 -115.584652       2020           8
# 151      MORAINE  36.727191 -118.551611       2020           8
# 152  RATTLESNAKE  36.430343 -118.415067       2020           8
# 153   STAGECOACH  35.453445 -118.484881       2020           8
#
#      Total_area_burned(ha)  Unchanged(ha)  Low_Severity(ha)  ...  \
# 0                   452.34           0.00              0.00  ...
# 1                  9384.21           0.72           5105.16  ...
# 2                   426.15          31.77            223.11  ...
# 3                  3294.18           1.80           1175.04  ...
# 4                   670.59           0.09            179.46  ...
# ..                     ...            ...               ...  ...
# 149               68846.58         652.86          10095.30  ...
# 150               17861.22           0.63           7155.81  ...
# 151                 526.32          16.83            290.07  ...
# 152                3354.03          44.46           1246.32  ...
# 153                3115.08           0.09            353.43  ...
#
#          NMOC(kg)       SO2(kg)       NH3(kg)       NO(kg)       NO2(kg)  \
# 0    5.521421e+05  1.778894e+04  3.629490e+04    28099.908  2.188601e+04
# 1    1.369784e+07  4.889210e+05  7.851947e+05   606988.143  5.544422e+05
# 2    3.079152e+05  1.091203e+04  1.991655e+04    16770.978  1.325578e+04
# 3    4.609133e+06  1.625256e+05  2.691405e+05   208178.550  1.861281e+05
# 4    1.271769e+06  4.919394e+04  6.355493e+04    48949.398  5.233612e+04
# ..            ...           ...           ...          ...           ...
# 149  1.257298e+08  4.862011e+06  6.307036e+06  4871243.853  5.181715e+06
# 150  1.999437e+07  6.090781e+05  1.397914e+06  1082047.968  7.835391e+05
# 151  5.614855e+05  2.151655e+04  2.917318e+04    22888.809  2.330114e+04
# 152  4.288664e+06  1.680807e+05  2.191925e+05   175511.088  1.809906e+05
# 153  4.119866e+06  1.404381e+05  2.524227e+05   195446.862  1.652619e+05
#
#          NOx(kg)     PM2.5(kg)        OC(kg)        BC(kg)  TSLF
# 0      44218.575  1.940653e+05  1.212313e+05  2.595684e+04     2
# 1     894041.793  5.423580e+06  4.790175e+06  4.384793e+05    10
# 2      26227.827  1.047941e+05  5.985273e+04  1.462841e+04     1
# 3     309643.182  1.798590e+06  1.534783e+06  1.563807e+05     0
# 4      66393.945  5.533168e+05  5.902289e+05  2.399313e+04     1
# ..           ...           ...           ...           ...   ...
# 149  6626948.121  5.452528e+07  5.785638e+07  2.421760e+06     0
# 150  1747069.398  6.589117e+06  3.105399e+06  1.088528e+06     0
# 151    31916.862  2.368573e+05  2.395223e+05  1.279837e+04     0
# 152   242955.450  1.814939e+06  1.852440e+06  9.317893e+04     0
# 153   297801.684  1.544650e+06  1.187603e+06  1.609667e+05     0
#
# [154 rows x 26 columns]

# %%
from datetime import date, timedelta
data1 = pd.read_csv("./region_4.csv")
data1['TSLF'] = 0
data1.sort_values(by=["Fire_Year","Fire_Month"], inplace=True)
data1.reset_index(inplace=True,drop=True)
for i in range(0, len(data1)-1):
    if data1.iloc[i+1]['Fire_Year'] > data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF'] = (((data1.iloc[i+1]['Fire_Year'] -  data1.iloc[i]['Fire_Year']) * 12) + data1.iloc[i+1]['Fire_Month']) - data1.iloc[i]['Fire_Month']
    if data1.iloc[i+1]['Fire_Year'] == data1.iloc[i]['Fire_Year']:
        data1.at[i,'TSLF']  = data1.iloc[i+1]['Fire_Month'] - data1.iloc[i]['Fire_Month']
data1
data1.to_csv('./region_4.csv')
data1
# Out:
#      Unnamed: 0                                           Event_ID  \
# 0          1493                              CA3606812023620170420
# 1          1495                              CA3611812036120170518
# 2          1482                              CA3539711882220170630
# 3          1483                              CA3539712049820170626
# 4          1485                              CA3557211858220170618
# ..          ...                                                ...
# 216        1680      CA20201117_20201123_UCM331_LAURA_2_CF00006431
# 217        1681  CA20201117_20201130_UCM332_MOUNTAIN_VIEW_CF000...
# 218        1637      CA20201201_20201213_UCM183_AIRPORT_CF00154602
# 219        1639    CA20201213_20201214_UCM187_SANDERSON_CF00160421
# 220        1688          CA20201203_20201207_UCM41_BOND_CF20136890
#
#          Fire_Name        Lat        Long  Fire_Year  Fire_Month  \
# 0            JAYNE  36.061000 -120.274000       2017           4
# 1            ELM 2  36.075000 -120.405000       2017           5
# 2           TARINA  35.385000 -118.793000       2017           6
# 3             HILL  35.405000 -120.481000       2017           6
# 4          HIGHWAY  35.586000 -118.574000       2017           6
# ..             ...        ...         ...        ...         ...
# 216        LAURA 2  40.062617 -120.089579       2020          11
# 217  MOUNTAIN VIEW  38.557839 -119.411412       2020          11
# 218        AIRPORT  33.902902 -117.627691       2020          12
# 219      SANDERSON  33.900438 -117.063063       2020          12
# 220           BOND  33.739796 -117.662660       2020          12
#
#      Total_area_burned(ha)  Unchanged(ha)  Low_Severity(ha)  ...    NMOC(kg)  \
# 0                  1892.16          36.09            282.96  ...   171294.48
# 1                  4357.44         238.41            855.72  ...  1340159.76
# 2                   508.86           0.81             52.65  ...      161.28
# 3                   765.90           2.79            288.36  ...   839710.08
# 4                   686.07           0.00            225.63  ...   275398.56
# ..                     ...            ...               ...  ...         ...
# 216                 929.43           0.00             68.58  ...   556638.48
# 217                5123.52          20.52            626.85  ...  6435782.64
# 218                 429.66          10.26            282.15  ...   181414.08
# 219                 784.62           2.97            148.95  ...   629028.00
# 220                2685.06           6.39            238.41  ...  2232208.08
#
#          SO2(kg)      NH3(kg)      NO(kg)      NO2(kg)     NOx(kg)  \
# 0     13391.2323    6659.3016   14546.295   14337.8874   20509.983
# 1     50767.7454   85558.8645   76548.789   61141.7691  119179.296
# 2        17.2800       3.2256      16.704      17.8560      22.464
# 3     26643.8178   56144.4768   43445.142   33167.8260   68867.982
# 4      9944.4294   15638.2308   12171.762   11225.2320   17846.622
# ..           ...          ...         ...          ...         ...
# 216   17259.0840   38196.9891   29567.889   21891.0465   47380.734
# 217  234277.5708  366589.1439  289054.269  265007.0997  424944.198
# 218    7100.2827    8872.8183    6836.400    7488.5607    9138.609
# 219   19597.0005   43359.8229   33840.864   24925.1877   54321.003
# 220   71575.6284  148965.4845  116264.511   88947.5679  184145.994
#
#        PM2.5(kg)       OC(kg)       BC(kg)  TSLF
# 0      48704.805    19870.695    4938.7977     1
# 1     445196.970   236075.436   64056.4452     1
# 2         41.472       14.976       2.1312     0
# 3     290250.558   170014.338   41147.0514     0
# 4     109506.762    97808.598    8596.7010     0
# ..           ...          ...          ...   ...
# 216   187219.872    97530.066   29023.4862     0
# 217  2538897.228  2232959.526  204937.4502     1
# 218    79930.917    87134.985    3080.8899     0
# 219   209489.931   104597.991   33294.7809     0
# 220   769291.452   446948.154  109413.1386     0
#
# [221 rows x 26 columns]
